# %% [markdown]
# # Trial 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # PCM1

# %% [markdown]
# There is a retroactively calculated 1.72 molar equivalence of $Na_{2}SO_{4}$ to 1 molar equivalence of $NaCl$.
# Water was brought to just below a boil and $Na_{2}SO_{4}$ was added until saturated. Xanthan gum was added as a thickening agent to keep crystals well dispersed. Trials will consist of tracking the temperature through time

# %% [markdown]
# ## Trial 1

# %% [markdown]
# Bag of about 500 mL of solution was pulled out of the freezer and set on lap. Measurments were taken over time. Measurments were taken by folding the bag over the thermommeter

# %%
Trial1_Times = [0,10,22,33,43,53,64,75]
Trial1_Temps = [10.6,14.0,20.0,23.3,25.2,25.7,27.2,28.3]

plt.plot(Trial1_Times,Trial1_Temps)
plt.title("PCM 1 Test 1")
plt.ylabel("Temp ($\degree{}$C)")
plt.xlabel("Time (min)")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\benny\AppData\Local\Temp\ipykernel_7040\3728402261.py:6: SyntaxWarning: invalid escape sequence '\d'
#   plt.ylabel("Temp ($\degree{}$C)")
# Text(0.5, 0, 'Time (min)')

# %% [markdown]
# ## Trial 2

# %% [markdown]
# Bag of about 500 mL of solution was pulled out of the freezer and set on lap. Measurments were taken over time. Measurments were taken by folding the bag over the thermommeter until 88.5 min had passed at which point the thermometer was submerged direclty in the solution.

# %%
Trial2_Times = [28,52,67,77,81,85,87,88.5,90,93,97,100,103,106,109,114,118,120,124,127,131,135,137,143,148,152,155,160,165]
Trial2_Temps = [-6.8,.2,10,9.1,12.6,15.4,15.9,18.9,17.8,19.2,20.3,21.5,22.3,22.4,23,23.4,23.7,24,24.8,24.8,25.8,25.8,26.3,26.5,26.5,26.7,26.7,27.4,27.4]
plt.scatter(Trial2_Times,Trial2_Temps)
plt.plot((88.5,88.5),(-6.5,27.4),color="Red",linewidth = 2,linestyle = "dotted")
plt.text(90,-5,"Measured Directly in PCM",color = "Red")
plt.title("PCM 1 Test 2")
plt.ylabel("Temp ($\\degree{}$C)")
plt.xlabel("Time (min)")
# Out:
# Text(0.5, 0, 'Time (min)')

# %% [markdown]
# I do not trust the above data. If there is a phase transition in this it is above what I am interested in.

# %% [markdown]
# In future experiments I will instead measure the freezing point as it should be the same as the melting point and will give a more steady flow of energy and a more predictable stopping point. Additionally I will not bae adding the xanthan gum so that I can get better stirring during experiments. Xanthan gum mixtures cna be added once the correct molar ratio of $Na_{2}SO_{4}$ to $NaCl$.
