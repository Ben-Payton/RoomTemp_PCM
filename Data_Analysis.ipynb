# %% [markdown]
# # Trial 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Trial1_Times = [0,10,22,33,43,53,64,75]
Trial2_Temps = [10.6,14.0,20.0,23.3,25.2,25.7,27.2,28.3]

plt.plot(Trial1_Times,Trial2_Temps)
plt.title("Trial1 PCM 1")
plt.ylabel("Temp ($\degree{}$C)")
plt.xlabel("Time (min)")
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\benny\AppData\Local\Temp\ipykernel_22372\519410723.py:6: SyntaxWarning: invalid escape sequence '\d'
#   plt.ylabel("Temp ($\degree{}$C)")
# Text(0.5, 0, 'Time (min)')
